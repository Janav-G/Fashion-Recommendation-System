# %%
import tensorflow 
from keras.applications.resnet import ResNet50, preprocess_input
from keras.layers import GlobalMaxPooling2D

# %%
model = ResNet50(weights="imagenet", include_top=False, input_shape=(224,224,3))
model.trainable = False

# %%
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
# ...

# %%
model = tensorflow.keras.Sequential([
    model,
    GlobalMaxPooling2D()
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_max_pooling2d (Glob  (None, 2048)              0
#  alMaxPooling2D)
#
# ...
# Total params: 23587712 (89.98 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
from tqdm import tqdm
import os
import cv2
import numpy as np
from numpy.linalg import norm

# %%
img = cv2.imread("C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\39546.jpg")
img = cv2.resize(img, (224,224))
#cv2.imshow("Frame",img)

# %%
#(number_of_image, 224, 224, 3)

# %%
img_shape = np.array(img)

# %%
img_shape.shape
# Out:
# (224, 224, 3)

# %%
expanded_img = np.expand_dims(img_shape, axis=0)

# %%
expanded_img.shape
# Out:
# (1, 224, 224, 3)

# %%
pre_img = preprocess_input(expanded_img)

# %%
pre_img.shape
# Out:
# (1, 224, 224, 3)

# %%
result = model.predict(pre_img).flatten()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
result
# Out:
# array([ 7.429688 ,  0.       , 14.408674 , ...,  5.0812387,  5.0449505,
#         4.417827 ], dtype=float32)

# %%
result.shape
# Out:
# (2048,)

# %%
normalized = result/norm(result)

# %%
normalized.shape
# Out:
# (2048,)

# %%
def extract_featrure(img_path, model):
    img = cv2.imread(img_path)
    #img = cv2.resize(img,(224,224),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
    img = cv2.resize(img, (224,224))
    img_shape = np.array(img)
    expanded_img = np.expand_dims(img_shape, axis=0)
    pre_img = preprocess_input(expanded_img)
    result = model.predict(pre_img).flatten()
    normalized = result/norm(result)
    return normalized

# %%
extract_featrure("C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\5426.jpg", model)
# Out:
# 1/1 [==============================] - 0s 150ms/step
# array([0.        , 0.09135984, 0.00677155, ..., 0.00908074, 0.0120653 ,
#        0.03751822], dtype=float32)

# %%
Extracted = []
feature_list = []

for file in os.listdir("C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset"):
    Extracted.append(os.path.join("C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset",file))

# %%
Extracted
# Out:
# ['C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\10037.jpg',
#  'C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\10039.jpg',
#  'C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\10054.jpg',
#  'C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\10096.jpg',
#  'C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\10097.jpg',
#  'C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\10110.jpg',
#  'C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\10174.jpg',
#  'C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\10180.jpg',
#  'C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\10266.jpg',
#  'C:\\Users\\g4jan\\Downloads\\Fashion Prediction using Deep Learning\\Dataset\\10267.jpg',
# ...

# %%
for file in tqdm(Extracted):
    feature_list.append(extract_featrure(file, model))
# Out:
# ...
#  16%|█▌        | 462/2906 [02:09<09:57,  4.09it/s]
# ...
# ...
# 100%|██████████| 2906/2906 [14:08<00:00,  3.42it/s]

# %%
import pickle

pickle.dump(feature_list, open("featurevector.pkl", "wb"))
pickle.dump(Extracted,open("filenames.pkl", "wb"))
